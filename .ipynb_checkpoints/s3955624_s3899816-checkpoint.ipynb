# %% [markdown]
# ---
# # <div align="center"><font color='green'> COSC 2673/2793 |  Machine Learning | Assignment 2 </font></div>
# ## <div align="center"> <font color='black'> Student Name: Chee Kin Go, Vincent Bethlehem </font></div>
# ## <div align="center"> <font color='red'> Student number: s3955624, s3899816 </font></div>
# ---

# %%
# To ensure Jupyter Notebook width size is same as your device viewport
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Problem statement
#
# As a team of machine learning engineers at a biomedical startup, the goal is to build two separate classification model in analyzing histopathology images of colon cells:
# - isCancerous Classification: Binary classification to determine whether a cell image represents cancerous cells
# - Cell-Type Classification: Multi-class classification to identify cell types (fibroblast, inflammatory, epithelial, or others)
#
# Various classification models are implemented and evaluated for each metrics:
# - isCancerous Classification:
#     - Baseline:
#     - Advanced:
#
# - Cell-Type Classification:
#      - Baseline:
#      - Advanced:
#
# By the end of evaluation, We aim to select the best-performing model for each classification method with justification

# %% [markdown]
# ## EDA, and Data Splitting

# %% [markdown]
# ### Assignment 2

# %% [markdown]
# Assignment Description Here

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import os

# %%
data = pd.read_csv('data_labels_mainData.csv', delimiter=',')
pd.set_option('display.max_columns', None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9896 entries, 0 to 9895
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   InstanceID    9896 non-null   int64
#  1   patientID     9896 non-null   int64
#  2   ImageName     9896 non-null   object
#  3   cellTypeName  9896 non-null   object
#  4   cellType      9896 non-null   int64
#  5   isCancerous   9896 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 464.0+ KB

# %%
data.isna().sum()
#check for null values
# Out:
# InstanceID      0
# patientID       0
# ImageName       0
# cellTypeName    0
# cellType        0
# isCancerous     0
# dtype: int64

# %%
plt.figure(figsize=(25,30))
#didnt do image name cause its not relevant
for i, col in enumerate([c for c in data.columns if c != 'ImageName']):
    plt.subplot(5, 6, i + 1)
    plt.hist(data[col], alpha=0.3, color='b', density=True)
    plt.title(col)
    plt.xticks(rotation='vertical')

# %%
plt.figure(figsize=(25, 30))

# Skipped ImageName and isCancerous (target variable)
features_to_plot = [col for col in data.columns if col not in ['ImageName', 'isCancerous']]

for i, col in enumerate(features_to_plot):
    plt.subplot(6, 5, i + 1)
    sns.scatterplot(data=data, x=col, y='isCancerous')
    plt.title(col)
    plt.xticks(rotation='vertical')

plt.tight_layout()
plt.show()

# %%
# correlation matrix
data_corr = data.corr(numeric_only=True)  # Excludes ImageName
# heatmap
plt.figure(figsize=(24, 20))
sns.heatmap(data_corr, fmt= '.2f', annot=True)

# Add title and layout adjustments
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
# unique cell type labels
cell_types = data['cellTypeName'].unique()
example_images = {}

# Choose random image
for cell in cell_types:
    one_row = data[data['cellTypeName'] == cell].sample(1)
    example_images[cell] = one_row['ImageName'].values[0]

# grid
fig, axes = plt.subplots(1, len(cell_types), figsize=(len(cell_types) * 5, 5))

# Loop selected image + display
for ax, (cell, filename) in zip(axes, example_images.items()):
    path = os.path.join("patch_images", filename)
    img = mpimg.imread(path)
    ax.imshow(img)
    ax.set_title(cell)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
with pd.option_context('mode.chained_assignment', None):

#Split once for test
    train_data, temp_data = train_test_split(data, test_size=0.4, shuffle=True, random_state=42)

#Split again for validation
    val_data, test_data = train_test_split(temp_data, test_size=0.5, shuffle=True, random_state=42)

print(f"Training data: {len(train_data)}")
print(f"Validation data: {len(val_data)}")
print(f"Test data: {len(test_data)}")
# Out:
# Training data: 5937
# Validation data: 1979
# Test data: 1980
